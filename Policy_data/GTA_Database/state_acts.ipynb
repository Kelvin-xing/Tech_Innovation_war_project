# %% [markdown]
# # Global Trade Alert
# from https://www.globaltradealert.org/data_extraction

# %%
import rdata
parsed = rdata.parser.parse_file('GTA_Database_2008_latest.Rdata')
converted = rdata.conversion.convert(parsed)
converted
# Out:
# /Users/mingjiexing/anaconda3/lib/python3.11/site-packages/rdata/conversion/_conversion.py:263: UserWarning: Exception while decoding b'Switzerland: Proposals to strengthen rules for"Made in Switzerland\x94 designations with implications for local content': 'utf-8' codec can't decode byte 0x94 in position 66: invalid start byte
#   warnings.warn(
# /Users/mingjiexing/anaconda3/lib/python3.11/site-packages/rdata/conversion/_conversion.py:263: UserWarning: Exception while decoding b'Thailand: \x93Blue Complex\x94 project of Commerce Ministry selling cheap products': 'utf-8' codec can't decode byte 0x93 in position 10: invalid start byte
#   warnings.warn(
# ...

# %%
import pyreadr

result = pyreadr.read_r('GTA_Database_2008_latest.Rdata')
print(result.keys())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/mingjiexing/Desktop/Python/Tech_Innovation_war_project/state_acts.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/Users/mingjiexing/Desktop/Python/Tech_Innovation_war_project/state_acts.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import pyreadr
# ----> <a href='vscode-notebook-cell:/Users/mingjiexing/Desktop/Python/Tech_Innovation_war_project/state_acts.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> result = pyreadr.read_r('GTA_Database_2008_latest.Rdata')
#       <a href='vscode-notebook-cell:/Users/mingjiexing/Desktop/Python/Tech_Innovation_war_project/state_acts.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> print(result.keys())
#
# File ~/anaconda3/lib/python3.11/site-packages/pyreadr/pyreadr.py:66, in read_r(path, use_objects, timezone)
#      64 if not os.path.isfile(filename_bytes):
# ...
